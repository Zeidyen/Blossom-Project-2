# %% [markdown]
# ## Abdulzeid and Kofi (Group 3)

# %%
#Importing libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Preliminary (Exploratory Data Analysis)

# %%
#Importing dataset
Training_Data=pd.read_csv("Train.csv")
Riders_Data=pd.read_csv("Riders.csv")

# %%
# Viewing first 5 rows of Training data 
Training_Data.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_25375  User_Id_2285         Bike              3
# 2   Order_No_1899   User_Id_265         Bike              3
# 3   Order_No_9336  User_Id_1402         Bike              3
# 4  Order_No_27883  User_Id_1737         Bike              1
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        12
# 2             Business                        30
# 3             Business                        15
# 4             Personal                        13
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5      11:16:16 AM                           12
# ...

# %%
# Viewing first 5 rows of Riders data 
Riders_Data.head()
# Out:
#        Rider Id  No_Of_Orders   Age  Average_Rating  No_of_Ratings
# 0  Rider_Id_396          2946  2298            14.0           1159
# 1  Rider_Id_479           360   951            13.5            176
# 2  Rider_Id_648          1746   821            14.3            466
# 3  Rider_Id_753           314   980            12.5             75
# 4  Rider_Id_335           536  1113            13.7            156

# %%
# Merging both Training and Riders dataset 
Merged_Data=Training_Data.merge(Riders_Data, on='Rider Id')

# %%
# Veiwing merged dataset
Merged_Data.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_27440  User_Id_2642         Bike              3
# 2  Order_No_14170  User_Id_3339         Bike              3
# 3  Order_No_21727  User_Id_3523         Bike              3
# 4   Order_No_8301    User_Id_87         Bike              2
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        18
# 2             Business                        31
# 3             Personal                         2
# 4             Personal                        22
#
#    Placement - Weekday (Mo = 1) Placement - Time  Confirmation - Day of Month  \
# 0                             5       9:35:46 AM                            9
# 1                             5       3:41:17 PM                           18
# ...

# %%
# Dataframe.size 
size = Merged_Data.size 

# Dataframe.shape 
shape = Merged_Data.shape

# Printing size and shape 
print("Size = {}\nShape ={}\nShape[0] x Shape[1] = {}". 
format(size, shape, shape[0]*shape[1]))
# Out:
# Size = 699633
# Shape =(21201, 33)
# Shape[0] x Shape[1] = 699633

# %%
# Creating a pivot table 
Merged_pivottable_Data=pd.pivot_table(Merged_Data,index=["Rider Id"])
Merged_pivottable_Data.head()
# Out:
#                Age  Arrival at Destination - Day of Month  \
# Rider Id
# Rider_Id_0    2570                               4.000000
# Rider_Id_1     589                              19.000000
# Rider_Id_10   1990                              18.078431
# Rider_Id_100   910                              14.222222
# Rider_Id_101   986                              16.612022
#
#               Arrival at Destination - Weekday (Mo = 1)  \
# Rider Id
# Rider_Id_0                                     1.000000
# Rider_Id_1                                     5.000000
# Rider_Id_10                                    3.607843
# Rider_Id_100                                   3.252525
# Rider_Id_101                                   3.311475
#
#               Arrival at Pickup - Day of Month  \
# Rider Id
# Rider_Id_0                            4.000000
# Rider_Id_1                           19.000000
# Rider_Id_10                          18.078431
# Rider_Id_100                         14.222222
# ...

# %%
# Obtaining the correlations 
Correlation_matrix=Merged_pivottable_Data.corr()
Correlation_matrix
# Out:
#                                                 Age  \
# Age                                        1.000000
# Arrival at Destination - Day of Month      0.058915
# Arrival at Destination - Weekday (Mo = 1) -0.105141
# Arrival at Pickup - Day of Month           0.058915
# Arrival at Pickup - Weekday (Mo = 1)      -0.105141
# Average_Rating                             0.178363
# Confirmation - Day of Month                0.058915
# Confirmation - Weekday (Mo = 1)           -0.105141
# Destination Lat                           -0.049529
# Destination Long                          -0.064597
# Distance (KM)                              0.119513
# No_Of_Orders                               0.715850
# No_of_Ratings                              0.641174
# Pickup - Day of Month                      0.058915
# Pickup - Weekday (Mo = 1)                 -0.105141
# Pickup Lat                                -0.029772
# Pickup Long                                0.000744
# ...

# %%
# Heatmap for correlation
f=plt.figure(figsize=(19,15))
plt.matshow(Correlation_matrix.corr(), fignum=f.number)
plt.xticks(range(Correlation_matrix.shape[1]),Correlation_matrix.columns,fontsize=14, rotation=90)
plt.yticks(range(Correlation_matrix.shape[1]),Correlation_matrix.columns,fontsize=14)
cb=plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation_matrix', fontsize=16)
# Out:
# Text(0.5, 1.05, 'Correlation_matrix')

# %%
Merged_Data.plot(kind = "scatter", x = 'Pickup Long', y = 'Pickup Lat', alpha = 1,
             c = 'Time from Pickup to Arrival', cmap = plt.get_cmap("jet"), figsize = (14, 10))

# %%
Merged_Data['Platform Type'].hist()

# %%
Merged_Data['Distance (KM)'].hist()

# %%
Merged_Data['Time from Pickup to Arrival'].hist()

# %%
Merged_Data.describe(include='all').transpose()
# Out:
#                                            count unique             top  \
# Order No                                   21201  21201  Order_No_21848
# User Id                                    21201   3186     User_Id_393
# Vehicle Type                               21201      1            Bike
# Platform Type                              21201    NaN             NaN
# Personal or Business                       21201      2        Business
# Placement - Day of Month                   21201    NaN             NaN
# Placement - Weekday (Mo = 1)               21201    NaN             NaN
# Placement - Time                           21201  15686      2:06:19 PM
# Confirmation - Day of Month                21201    NaN             NaN
# Confirmation - Weekday (Mo = 1)            21201    NaN             NaN
# Confirmation - Time                        21201  15742      9:56:52 AM
# Arrival at Pickup - Day of Month           21201    NaN             NaN
# ...

# %%
Merged_Data[['Age', 'No_Of_Orders']].plot.kde(bw_method=0.3)

# %%
Merged_Data["Arrival at Destination - Weekday (Mo = 1)"].value_counts().plot(kind='bar')

# %%
Merged_Data["Arrival at Pickup - Weekday (Mo = 1)"].hist()

# %%
Merged_Data.boxplot(column=['Temperature','Precipitation in millimeters'])

# %%
#stats_on_merged_Data=Merged_Data.describe()
#stats_on_merged_Data

Merged_pivottable_Data=Merged_Data.describe()
Merged_pivottable_Data
# Out:
#        Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# count   21201.000000              21201.000000                  21201.000000
# mean        2.752182                 15.653696                      3.240083
# std         0.625178                  8.798916                      1.567295
# min         1.000000                  1.000000                      1.000000
# 25%         3.000000                  8.000000                      2.000000
# 50%         3.000000                 15.000000                      3.000000
# 75%         3.000000                 23.000000                      5.000000
# max         4.000000                 31.000000                      7.000000
#
#        Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# count                 21201.000000                     21201.000000
# mean                     15.653837                         3.240225
# std                       8.798886                         1.567228
# ...

# %%
Merged_Data.hist(bins = 60, figsize = (20, 15))

plt.show()

# %%
cor_of_dayofmonth=Merged_Data[["Placement - Day of Month", "Confirmation - Day of Month", "Arrival at Pickup - Day of Month","Pickup - Day of Month", "Arrival at Destination - Day of Month"]]

# %% [markdown]
# # Checking for Missingness in Dataset

# %%
# Importing Libraries 
#!conda install --yes --prefix {sys.prefix} pandas-profiling
#!{sys.executable} -m pip install missingno
import sys
import missingno as miss

# %%
# Visualising missing data  
miss.matrix(Merged_Data)

# %%
# Checking for total number of missing values in the dataset 
Missing_values = Merged_Data.isnull().sum()
Missing_values
# Out:
# Order No                                         0
# User Id                                          0
# Vehicle Type                                     0
# Platform Type                                    0
# Personal or Business                             0
# Placement - Day of Month                         0
# Placement - Weekday (Mo = 1)                     0
# Placement - Time                                 0
# Confirmation - Day of Month                      0
# Confirmation - Weekday (Mo = 1)                  0
# Confirmation - Time                              0
# Arrival at Pickup - Day of Month                 0
# Arrival at Pickup - Weekday (Mo = 1)             0
# Arrival at Pickup - Time                         0
# Pickup - Day of Month                            0
# Pickup - Weekday (Mo = 1)                        0
# Pickup - Time                                    0
# Arrival at Destination - Day of Month            0
# ...

# %%
# Checking for the percentage of missing values in the dataset 
Missing_values = Merged_Data.isnull().sum()/21201*100
Missing_values_percentageTemp=Missing_values["Temperature"]
Missing_values_percentagePrep=Missing_values["Precipitation in millimeters"]

# Printing the percentage of missing values in the dataset 
print("Percentage of Missing values for Temperature = {}\nPercentage of Missing values for Precipitation = {}". 
format(Missing_values_percentageTemp, Missing_values_percentagePrep))
# Out:
# Percentage of Missing values for Temperature = 20.593368237347295
# Percentage of Missing values for Precipitation = 97.39634922880997

# %%
# Taking care of misssing data 
from sklearn.preprocessing import Imputer
imputer=Imputer(missing_values="NaN", strategy="mean", axis=0)
imputer=imputer.fit(Merged_Data[["Temperature","Precipitation in millimeters"]])
Transform_Merged_Data=imputer.transform(Merged_Data[["Temperature","Precipitation in millimeters"]])
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
Missing_values = Merged_Data.isnull().sum()
Missing_values
# Out:
# Order No                                         0
# User Id                                          0
# Vehicle Type                                     0
# Platform Type                                    0
# Personal or Business                             0
# Placement - Day of Month                         0
# Placement - Weekday (Mo = 1)                     0
# Placement - Time                                 0
# Confirmation - Day of Month                      0
# Confirmation - Weekday (Mo = 1)                  0
# Confirmation - Time                              0
# Arrival at Pickup - Day of Month                 0
# Arrival at Pickup - Weekday (Mo = 1)             0
# Arrival at Pickup - Time                         0
# Pickup - Day of Month                            0
# Pickup - Weekday (Mo = 1)                        0
# Pickup - Time                                    0
# Arrival at Destination - Day of Month            0
# ...

# %%
# Deleting Precipitation in millimeters feature 
del Merged_Data['Precipitation in millimeters']

# %%
# Checking missing data  
Missing_values = Merged_Data.isnull().sum()
Missing_values
# Out:
# Order No                                        0
# User Id                                         0
# Vehicle Type                                    0
# Platform Type                                   0
# Personal or Business                            0
# Placement - Day of Month                        0
# Placement - Weekday (Mo = 1)                    0
# Placement - Time                                0
# Confirmation - Day of Month                     0
# Confirmation - Weekday (Mo = 1)                 0
# Confirmation - Time                             0
# Arrival at Pickup - Day of Month                0
# Arrival at Pickup - Weekday (Mo = 1)            0
# Arrival at Pickup - Time                        0
# Pickup - Day of Month                           0
# Pickup - Weekday (Mo = 1)                       0
# Pickup - Time                                   0
# Arrival at Destination - Day of Month           0
# Arrival at Destination - Weekday (Mo = 1)       0
# ...

# %% [markdown]
# ### Analysis on Missingness of Data
#
# **Observations**
#
#
# From the computations made, we observed that a total of 25,015 missing data which reperesent 4.9% of the total dataset.
#
# | Feature      |Type of Feature | Number of Missing Values    | Percentage of Missing Values   |
# | :------------- |:--------------:| :----------: | -----------: |
# |  Precipitation in millimeters  |Numeric values|20649     |  `97.4%` |
# | Temperature   |Numeric values |4366 | `20.6%`|
#
# From the above table all missing values are found in the Precipitation in millimeters which has 20649 reperesenting (97.4%) missing values and Temperature which has  4366 (20.6%)  missing values. And all the fetures ares are numeric by variable discription.

# %% [markdown]
# ## Feature Engineering for Training Test

# %%
#from sklearn.preprocessing import LabelEncoder,OneHotEncoder
#labelencoder_X=LabelEncoder()
#Merged_Data['Personal or Business']=labelencoder_X.fit_transform(Merged_Data['Personal or Business'])
#Merged_Data.head()

# %%
Test_Data = pd.read_csv('Test.csv')
Riders = pd.read_csv('Riders.csv')
Merged_Test_Data = pd.merge(Test_Data,Riders)

# %%
Merged_Data_Feature = Merged_Data.copy()
Merged_Test_Feature = Merged_Test_Data.copy()
Merged_Data_Feature.columns
# Out:
# Index(['Order No', 'User Id', 'Vehicle Type', 'Platform Type',
#        'Personal or Business', 'Placement - Day of Month',
#        'Placement - Weekday (Mo = 1)', 'Placement - Time',
#        'Confirmation - Day of Month', 'Confirmation - Weekday (Mo = 1)',
#        'Confirmation - Time', 'Arrival at Pickup - Day of Month',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Arrival at Pickup - Time',
#        'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)', 'Pickup - Time',
#        'Arrival at Destination - Day of Month',
#        'Arrival at Destination - Weekday (Mo = 1)',
#        'Arrival at Destination - Time', 'Distance (KM)', 'Temperature',
#        'Precipitation in millimeters', 'Pickup Lat', 'Pickup Long',
#        'Destination Lat', 'Destination Long', 'Rider Id',
#        'Time from Pickup to Arrival', 'No_Of_Orders', 'Age', 'Average_Rating',
#        'No_of_Ratings'],
#       dtype='object')

# %%
################################ Encoding Time Stamps ############
from datetime import datetime
Merged_Data_Feature['Placement - Time'] = Merged_Data_Feature['Placement - Time'].apply(lambda x: datetime.strptime(x,'%I:%M:%S %p'))
Merged_Data_Feature['Confirmation - Time'] = Merged_Data_Feature['Confirmation - Time'].apply(lambda x: datetime.strptime(x,'%I:%M:%S %p'))
Merged_Data_Feature['Pickup - Time'] = Merged_Data_Feature['Pickup - Time'].apply(lambda x: datetime.strptime(x,'%I:%M:%S %p'))
Merged_Data_Feature['Arrival at Destination - Time'] = Merged_Data_Feature['Arrival at Destination - Time'].apply(lambda x: datetime.strptime(x,'%I:%M:%S %p'))
Merged_Data_Feature['Arrival at Pickup - Time'] = Merged_Data_Feature['Arrival at Pickup - Time'].apply(lambda x: datetime.strptime(x,'%I:%M:%S %p'))
#####################################
Merged_Test_Feature['Placement - Time'] = Merged_Test_Feature['Placement - Time'].apply(lambda x: datetime.strptime(x,'%I:%M:%S %p'))
Merged_Test_Feature['Confirmation - Time'] = Merged_Test_Feature['Confirmation - Time'].apply(lambda x: datetime.strptime(x,'%I:%M:%S %p'))
Merged_Test_Feature['Pickup - Time'] = Merged_Test_Feature['Pickup - Time'].apply(lambda x: datetime.strptime(x,'%I:%M:%S %p'))
#Merged_Test_Feature['Arrival at Destination - Time'] = Merged_Test_Feature['Arrival at Destination - Time'].apply(lambda x: datetime.strptime(x,'%I:%M:%S %p'))
Merged_Test_Feature['Arrival at Pickup - Time'] = Merged_Test_Feature['Arrival at Pickup - Time'].apply(lambda x: datetime.strptime(x,'%I:%M:%S %p'))
#####################################

# %%
Merged_Data_Feature['Placement Time of day'] = Merged_Data_Feature['Placement - Time'].dt.hour
Merged_Data_Feature['Confirmation Time of day'] = Merged_Data_Feature['Confirmation - Time'].dt.hour
Merged_Data_Feature['Pickup Time of day'] = Merged_Data_Feature['Pickup - Time'].dt.hour
Merged_Data_Feature['Arrival Time of day'] = Merged_Data_Feature['Arrival at Destination - Time'].dt.hour
Merged_Data_Feature['Arrival Time Pickup of day'] = Merged_Data_Feature['Arrival at Pickup - Time'].dt.hour
##################################
Merged_Test_Feature['Placement Time of day'] = Merged_Test_Feature['Placement - Time'].dt.hour
Merged_Test_Feature['Confirmation Time of day'] = Merged_Test_Feature['Confirmation - Time'].dt.hour
Merged_Test_Feature['Pickup Time of day'] = Merged_Test_Feature['Pickup - Time'].dt.hour
#Merged_Data_Feature['Arrival Time of day'] = Merged_Data_Feature['Arrival at Destination - Time'].dt.hour
Merged_Test_Feature['Arrival Time Pickup of day'] = Merged_Test_Feature['Arrival at Pickup - Time'].dt.hour
##################################

# %%
def hr(hour):
    if (hour > 4) and (hour <= 12):
        return 'Morning'
    elif (hour >= 12) and (hour <= 16):
        return'Afternoon'
    elif (hour > 16) and (hour <= 20):
        return 'Evening'
    elif (hour > 20) and (hour <= 22):
        return'Night'
    else:
        return'Mid-Night'

Merged_Data_Feature['Placement Time of day'] = Merged_Data_Feature['Placement Time of day'].apply(hr)
#################################################

def hr(hour):
    if (hour > 4) and (hour <= 12):
        return 'Morning'
    elif (hour >= 12) and (hour <= 16):
        return'Afternoon'
    elif (hour > 16) and (hour <= 20):
        return 'Evening'
    elif (hour > 20) and (hour <= 22):
        return'Night'
    else:
        return'Mid-Night'

Merged_Test_Feature['Placement Time of day'] = Merged_Test_Feature['Placement Time of day'].apply(hr)

# %%
def hr(hour):
    if (hour > 4) and (hour <= 12):
        return 'Morning'
    elif (hour >= 12) and (hour <= 16):
        return'Afternoon'
    elif (hour > 16) and (hour <= 20):
        return 'Evening'
    elif (hour > 20) and (hour <= 22):
        return'Night'
    else:
        return'Mid-Night'

Merged_Data_Feature['Confirmation Time of day'] = Merged_Data_Feature['Confirmation Time of day'].apply(hr)
#########################
def hr(hour):
    if (hour > 4) and (hour <= 12):
        return 'Morning'
    elif (hour >= 12) and (hour <= 16):
        return'Afternoon'
    elif (hour > 16) and (hour <= 20):
        return 'Evening'
    elif (hour > 20) and (hour <= 22):
        return'Night'
    else:
        return'Mid-Night'

Merged_Test_Feature['Confirmation Time of day'] = Merged_Test_Feature['Confirmation Time of day'].apply(hr)

# %%
def hr(hour):
    if (hour > 4) and (hour <= 12):
        return 'Morning'
    elif (hour >= 12) and (hour <= 16):
        return'Afternoon'
    elif (hour > 16) and (hour <= 20):
        return 'Evening'
    elif (hour > 20) and (hour <= 22):
        return'Night'
    else:
        return'Mid-Night'

Merged_Data_Feature['Pickup Time of day'] = Merged_Data_Feature['Pickup Time of day'].apply(hr)
####################################

def hr(hour):
    if (hour > 4) and (hour <= 12):
        return 'Morning'
    elif (hour >= 12) and (hour <= 16):
        return'Afternoon'
    elif (hour > 16) and (hour <= 20):
        return 'Evening'
    elif (hour > 20) and (hour <= 22):
        return'Night'
    else:
        return'Mid-Night'

Merged_Test_Feature['Pickup Time of day'] = Merged_Test_Feature['Pickup Time of day'].apply(hr)

# %%
def hr(hour):
    if (hour > 4) and (hour <= 12):
        return 'Morning'
    elif (hour >= 12) and (hour <= 16):
        return'Afternoon'
    elif (hour > 16) and (hour <= 20):
        return 'Evening'
    elif (hour > 20) and (hour <= 22):
        return'Night'
    else:
        return'Mid-Night'

Merged_Data_Feature['Arrival Time of day'] = Merged_Data_Feature['Arrival Time of day'].apply(hr)

# %%
def hr(hour):
    if (hour > 4) and (hour <= 12):
        return 'Morning'
    elif (hour >= 12) and (hour <= 16):
        return'Afternoon'
    elif (hour > 16) and (hour <= 20):
        return 'Evening'
    elif (hour > 20) and (hour <= 22):
        return'Night'
    else:
        return'Mid-Night'

Merged_Data_Feature['Arrival Time Pickup of day'] = Merged_Data_Feature['Arrival Time Pickup of day'].apply(hr)
########################################################
def hr(hour):
    if (hour > 4) and (hour <= 12):
        return 'Morning'
    elif (hour >= 12) and (hour <= 16):
        return'Afternoon'
    elif (hour > 16) and (hour <= 20):
        return 'Evening'
    elif (hour > 20) and (hour <= 22):
        return'Night'
    else:
        return'Mid-Night'

Merged_Test_Feature['Arrival Time Pickup of day'] = Merged_Test_Feature['Arrival Time Pickup of day'].apply(hr)

# %%
Merged_Data_Feature['Placement day'] = np.where(Merged_Data_Feature['Placement - Weekday (Mo = 1)']<6, 'Weekday', 'Weekend')
Merged_Data_Feature['Confirmation day'] = np.where(Merged_Data_Feature['Confirmation - Weekday (Mo = 1)']<6, 'Weekday', 'Weekend')
Merged_Data_Feature['Pickup day'] = np.where(Merged_Data_Feature['Pickup - Weekday (Mo = 1)']<6, 'Weekday', 'Weekend')
Merged_Data_Feature['Arrival at Destination day'] = np.where(Merged_Data_Feature['Arrival at Destination - Weekday (Mo = 1)']<6, 'Weekday', 'Weekend')
Merged_Data_Feature['Arrival at Pickup day'] = np.where(Merged_Data_Feature['Arrival at Pickup - Weekday (Mo = 1)']<6, 'Weekday', 'Weekend')
##################################
Merged_Test_Feature['Placement day'] = np.where(Merged_Test_Feature['Placement - Weekday (Mo = 1)']<6, 'Weekday', 'Weekend')
Merged_Test_Feature['Confirmation day'] = np.where(Merged_Test_Feature['Confirmation - Weekday (Mo = 1)']<6, 'Weekday', 'Weekend')
Merged_Test_Feature['Pickup day'] = np.where(Merged_Test_Feature['Pickup - Weekday (Mo = 1)']<6, 'Weekday', 'Weekend')
#Merged_Data_Feature['Arrival at Destination day'] = np.where(Merged_Data_Feature['Arrival at Destination - Weekday (Mo = 1)']<6, 'Weekday', 'Weekend')
Merged_Test_Feature['Arrival at Pickup day'] = np.where(Merged_Test_Feature['Arrival at Pickup - Weekday (Mo = 1)']<6, 'Weekday', 'Weekend')

# %%
Merged_Data_Feature.columns
# Out:
# Index(['Order No', 'User Id', 'Vehicle Type', 'Platform Type',
#        'Personal or Business', 'Placement - Day of Month',
#        'Placement - Weekday (Mo = 1)', 'Placement - Time',
#        'Confirmation - Day of Month', 'Confirmation - Weekday (Mo = 1)',
#        'Confirmation - Time', 'Arrival at Pickup - Day of Month',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Arrival at Pickup - Time',
#        'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)', 'Pickup - Time',
#        'Arrival at Destination - Day of Month',
#        'Arrival at Destination - Weekday (Mo = 1)',
#        'Arrival at Destination - Time', 'Distance (KM)', 'Temperature',
#        'Precipitation in millimeters', 'Pickup Lat', 'Pickup Long',
#        'Destination Lat', 'Destination Long', 'Rider Id',
#        'Time from Pickup to Arrival', 'No_Of_Orders', 'Age', 'Average_Rating',
#        'No_of_Ratings', 'Placement Time of day', 'Confirmation Time of day',
# ...

# %%
Merged_Test_Feature.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0  Order_No_19248  User_Id_3355         Bike              3
# 1   Order_No_2699   User_Id_592         Bike              1
# 2  Order_No_21486   User_Id_478         Bike              3
# 3  Order_No_19336  User_Id_2801         Bike              3
# 4  Order_No_20374  User_Id_3465         Bike              3
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                        27
# 1             Personal                        26
# 2             Business                        29
# 3             Business                         2
# 4             Business                        14
#
#    Placement - Weekday (Mo = 1)    Placement - Time  \
# 0                             3 1900-01-01 16:44:10
# 1                             2 1900-01-01 14:43:21
# 2                             5 1900-01-01 11:55:05
# 3                             1 1900-01-01 09:23:21
# ...

# %% [markdown]
# #### Feature Engineering for Destination

# %%
import sys
# !{sys.executable} -m pip install geopy

# %%
# importing geodesic from geopy 
from geopy.distance import geodesic

# Creating a column for CBD proximity and populating it with Nan
Merged_Data_Feature['Proximity to Pickup Point'] = np.nan

# Latitude and longitude for Central Business District of Nairobi
CBD_Nairobi=(-1.299719, 36.816097)

# Iterating through Data to compute for Distance(km)
for i, row in Merged_Data_Feature.iterrows():
    Merged_Data_Feature.loc[i, 'Proximity to Pickup Point'] = geodesic((Merged_Data_Feature.loc[i, 'Pickup Lat'],
                                                                  Merged_Data_Feature.loc[i, 'Pickup Long']),CBD_Nairobi).km

# %%
# importing geodesic from geopy 
from geopy.distance import geodesic

# Creating a column for CBD proximity and populating it with Nan
Merged_Test_Feature['Proximity to Pickup Point'] = np.nan

# Latitude and longitude for Central Business District of Nairobi
CBD_Nairobi=(-1.299719, 36.816097)

# Iterating through Data to compute for Distance(km)
for i, row in Merged_Test_Feature.iterrows():
    Merged_Test_Feature.loc[i, 'Proximity to Pickup Point'] = geodesic((Merged_Test_Feature.loc[i, 'Pickup Lat'],
                                                                  Merged_Test_Feature.loc[i, 'Pickup Long']),CBD_Nairobi).km

# %%
# importing geodesic from geopy 
from geopy.distance import geodesic

#Creating a column for CBD proximity and populating it with Nan
Merged_Data_Feature['Proximity to Destination'] = np.nan

# Latitude and longitude for Central Business District of Nairobi
CBD_Nairobi=(-1.299719, 36.816097)

# Iterating through Data to compute for Distance (KM)
for i, row in Merged_Data_Feature.iterrows():
    Merged_Data_Feature.loc[i, 'Proximity to Destination'] = geodesic((Merged_Data_Feature.loc[i, 'Destination Lat'],
                                                                  Merged_Data_Feature.loc[i, 'Destination Long']),CBD_Nairobi).km

# %%
# importing geodesic from geopy 
from geopy.distance import geodesic

#Creating a column for CBD proximity and populating it with Nan
Merged_Test_Feature['Proximity to Destination'] = np.nan

# Latitude and longitude for Central Business District of Nairobi
CBD_Nairobi=(-1.299719, 36.816097)

# Iterating through Data to compute for Distance (KM)
for i, row in Merged_Test_Feature.iterrows():
    Merged_Test_Feature.loc[i, 'Proximity to Destination'] = geodesic((Merged_Test_Feature.loc[i, 'Destination Lat'],
                                                                  Merged_Test_Feature.loc[i, 'Destination Long']),CBD_Nairobi).km

# %%
Merged_Data_Feature.head()
# Out:
#          Order No       User Id Vehicle Type  Platform Type  \
# 0   Order_No_4211   User_Id_633         Bike              3
# 1  Order_No_27440  User_Id_2642         Bike              3
# 2  Order_No_14170  User_Id_3339         Bike              3
# 3  Order_No_21727  User_Id_3523         Bike              3
# 4   Order_No_8301    User_Id_87         Bike              2
#
#   Personal or Business  Placement - Day of Month  \
# 0             Business                         9
# 1             Personal                        18
# 2             Business                        31
# 3             Personal                         2
# 4             Personal                        22
#
#    Placement - Weekday (Mo = 1)    Placement - Time  \
# 0                             5 1900-01-01 09:35:46
# 1                             5 1900-01-01 15:41:17
# 2                             5 1900-01-01 12:51:41
# 3                             2 1900-01-01 07:12:10
# ...

# %%
Temperature_Deg = []

# Using a for loop to populate the list
for Degree in Merged_Data_Feature['Temperature']:
    if (Degree >= 15) and (Degree <= 27):
        Temperature_Deg.append('Not Favourable')
    elif (Degree >= 12) and (Degree <= 22 ):
        Temperature_Deg.append('Not Favourable')
    else:
        Temperature_Deg.append('Favourable')

# Storing the data as a column in Featured_Data
Merged_Data_Feature['Temperature Condition'] = Temperature_Deg

#############################################################
Temperature_Deg = []

# Using a for loop to populate the list
for Degree in Merged_Test_Feature['Temperature']:
    if (Degree >= 15) and (Degree <= 27):
        Temperature_Deg.append('Not Favourable')
    elif (Degree >= 12) and (Degree <= 22 ):
        Temperature_Deg.append('Not Favourable')
    else:
        Temperature_Deg.append('Favourable')

# Storing the data as a column in Featured_Data
Merged_Test_Feature['Temperature Condition'] = Temperature_Deg

# %%
# Create a list to store the data
Place_Day_Month = []

# Using a for loop to populate the list
for Each_Day in Merged_Data_Feature['Placement - Day of Month']:
    if (Each_Day > 0 and Each_Day <=7):
        Place_Day_Month.append('1st Week')        
    elif (Each_Day > 7 and Each_Day <=15):
        Place_Day_Month.append('2nd Week')
    elif (Each_Day > 15 and Each_Day <=23):
        Place_Day_Month.append('3rd Week')
    else:
        Place_Day_Month.append('4th Week')
            
# Storing the data as a column in Featured_Data
Merged_Data_Feature['Placement Day into Weeks'] = Place_Day_Month

########################################################################

# Create a list to store the data
Place_Day_Month = []

# Using a for loop to populate the list
for Each_Day in Merged_Test_Feature['Placement - Day of Month']:
    if (Each_Day > 0 and Each_Day <=7):
        Place_Day_Month.append('1st Week')        
    elif (Each_Day > 7 and Each_Day <=15):
        Place_Day_Month.append('2nd Week')
    elif (Each_Day > 15 and Each_Day <=23):
        Place_Day_Month.append('3rd Week')
    else:
        Place_Day_Month.append('4th Week')
            
# Storing the data as a column in Featured_Data
Merged_Test_Feature['Placement Day into Weeks'] = Place_Day_Month

# %%
# Encoding Train data in various weeks 
Confirm_Day_Month = []

for Each_Day in Merged_Data_Feature['Confirmation - Day of Month']:
    if (Each_Day > 0 and Each_Day <=7):
        Confirm_Day_Month.append('1st Week')        
    elif (Each_Day > 7 and Each_Day <=15):
        Confirm_Day_Month.append('2nd Week')
    elif (Each_Day > 15 and Each_Day <=23):
        Confirm_Day_Month.append('3rd Week')
    else:
        Confirm_Day_Month.append('4th Week')
            

Merged_Data_Feature['Confirmation Day into Weeks'] = Confirm_Day_Month


##############################################

# Encoding Test data in various weeks 
Confirm_Day_Month = []

# Using a for loop to populate the list
for Each_Day in Merged_Test_Feature['Confirmation - Day of Month']:
    if (Each_Day > 0 and Each_Day <=7):
        Confirm_Day_Month.append('1st Week')        
    elif (Each_Day > 7 and Each_Day <=15):
        Confirm_Day_Month.append('2nd Week')
    elif (Each_Day > 15 and Each_Day <=23):
        Confirm_Day_Month.append('3rd Week')
    else:
        Confirm_Day_Month.append('4th Week')
          
Merged_Test_Feature['Confirmation Day into Weeks'] = Confirm_Day_Month

# %%
# Encoding Train data in various weeks 
Arrival_Pickup_Day_Month=[]

for Each_Day in Merged_Data_Feature['Arrival at Pickup - Day of Month']:
    if (Each_Day > 0 and Each_Day <=7):
        Arrival_Pickup_Day_Month.append('1st Week')        
    elif (Each_Day > 7 and Each_Day <=15):
        Arrival_Pickup_Day_Month.append('2nd Week')
    elif (Each_Day > 15 and Each_Day <=23):
        Arrival_Pickup_Day_Month.append('3rd Week')
    else:
        Arrival_Pickup_Day_Month.append('4th Week')
            

Merged_Data_Feature['Arrival_Pickup_Day into Weeks'] = Arrival_Pickup_Day_Month

##############################

# Encoding Test data in various weeks 
Arrival_Pickup_Day_Month=[]


for Each_Day in Merged_Test_Feature['Arrival at Pickup - Day of Month']:
    if (Each_Day > 0 and Each_Day <=7):
        Arrival_Pickup_Day_Month.append('1st Week')        
    elif (Each_Day > 7 and Each_Day <=15):
        Arrival_Pickup_Day_Month.append('2nd Week')
    elif (Each_Day > 15 and Each_Day <=23):
        Arrival_Pickup_Day_Month.append('3rd Week')
    else:
        Arrival_Pickup_Day_Month.append('4th Week')
            

Merged_Test_Feature['Arrival_Pickup_Day into Weeks'] = Arrival_Pickup_Day_Month

# %%
# Encoding Train data in various weeks 
Pickup_Day_Month = []


for Each_Day in Merged_Data_Feature['Pickup - Day of Month']:
    if (Each_Day > 0 and Each_Day <=7):
        Pickup_Day_Month.append('1st Week')        
    elif (Each_Day > 7 and Each_Day <=15):
        Pickup_Day_Month.append('2nd Week')
    elif (Each_Day > 15 and Each_Day <=23):
        Pickup_Day_Month.append('3rd Week')
    else:
        Pickup_Day_Month.append('4th Week')
            

Merged_Data_Feature['Pickup_Day into Weeks'] = Pickup_Day_Month

###############################################################

# Encoding Test data in various weeks 
Pickup_Day_Month = []


for Each_Day in Merged_Test_Feature['Pickup - Day of Month']:
    if (Each_Day > 0 and Each_Day <=7):
        Pickup_Day_Month.append('1st Week')        
    elif (Each_Day > 7 and Each_Day <=15):
        Pickup_Day_Month.append('2nd Week')
    elif (Each_Day > 15 and Each_Day <=23):
        Pickup_Day_Month.append('3rd Week')
    else:
        Pickup_Day_Month.append('4th Week')
            
# Storing the data as a column in Featured_Data
Merged_Test_Feature['Pickup_Day into Weeks'] = Pickup_Day_Month

# %%
# Create a list to store the data
Arrival_Destn_Day_Month = []

# Using a for loop to populate the list
for Each_Day in Merged_Data_Feature['Arrival at Destination - Day of Month']:
    if (Each_Day > 0 and Each_Day <=7):
        Arrival_Destn_Day_Month.append('1st Week')        
    elif (Each_Day > 7 and Each_Day <=15):
        Arrival_Destn_Day_Month.append('2nd Week')
    elif (Each_Day > 15 and Each_Day <=23):
        Arrival_Destn_Day_Month.append('3rd Week')
    else:
        Arrival_Destn_Day_Month.append('4th Week')
            
# Storing the data as a column in Featured_Data
Merged_Data_Feature['Arrival Destination Day into Weeks'] = Arrival_Destn_Day_Month

# %%
Merged_Data_Feature.columns
# Out:
# Index(['Order No', 'User Id', 'Vehicle Type', 'Platform Type',
#        'Personal or Business', 'Placement - Day of Month',
#        'Placement - Weekday (Mo = 1)', 'Placement - Time',
#        'Confirmation - Day of Month', 'Confirmation - Weekday (Mo = 1)',
#        'Confirmation - Time', 'Arrival at Pickup - Day of Month',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Arrival at Pickup - Time',
#        'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)', 'Pickup - Time',
#        'Arrival at Destination - Day of Month',
#        'Arrival at Destination - Weekday (Mo = 1)',
#        'Arrival at Destination - Time', 'Distance (KM)', 'Temperature',
#        'Precipitation in millimeters', 'Pickup Lat', 'Pickup Long',
#        'Destination Lat', 'Destination Long', 'Rider Id',
#        'Time from Pickup to Arrival', 'No_Of_Orders', 'Age', 'Average_Rating',
#        'No_of_Ratings', 'Placement Time of day', 'Confirmation Time of day',
# ...

# %%
New_Data_Train = Merged_Data_Feature.drop(["Order No","User Id","Vehicle Type","Rider Id", "Pickup Long", "Destination Long", "Pickup Lat", "Destination Lat",
"Average_Rating","Temperature","Precipitation in millimeters"], axis=1)
New_Data_Test= Merged_Test_Feature.drop(["Order No","User Id","Vehicle Type","Rider Id", "Pickup Long", "Destination Long", "Pickup Lat", "Destination Lat",
"Average_Rating","Temperature","Precipitation in millimeters"], axis=1)

# %%
New_Data_Train.to_csv('Training_Features.csv')
New_Data_Test.to_csv('Testing_Features.csv')
New_Data_Train.columns
# Out:
# Index(['Platform Type', 'Personal or Business', 'Placement - Day of Month',
#        'Placement - Weekday (Mo = 1)', 'Placement - Time',
#        'Confirmation - Day of Month', 'Confirmation - Weekday (Mo = 1)',
#        'Confirmation - Time', 'Arrival at Pickup - Day of Month',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Arrival at Pickup - Time',
#        'Pickup - Day of Month', 'Pickup - Weekday (Mo = 1)', 'Pickup - Time',
#        'Arrival at Destination - Day of Month',
#        'Arrival at Destination - Weekday (Mo = 1)',
#        'Arrival at Destination - Time', 'Distance (KM)',
#        'Time from Pickup to Arrival', 'No_Of_Orders', 'Age', 'No_of_Ratings',
#        'Placement Time of day', 'Confirmation Time of day',
#        'Pickup Time of day', 'Arrival Time of day',
#        'Arrival Time Pickup of day', 'Placement day', 'Confirmation day',
#        'Pickup day', 'Arrival at Destination day', 'Arrival at Pickup day',
# ...

# %%
Numeric_Train_Data = New_Data_Train._get_numeric_data()
Numeric_Test_Data = New_Data_Test._get_numeric_data()
Numeric_Train_Data.columns
# Out:
# Index(['Platform Type', 'Placement - Day of Month',
#        'Placement - Weekday (Mo = 1)', 'Confirmation - Day of Month',
#        'Confirmation - Weekday (Mo = 1)', 'Arrival at Pickup - Day of Month',
#        'Arrival at Pickup - Weekday (Mo = 1)', 'Pickup - Day of Month',
#        'Pickup - Weekday (Mo = 1)', 'Arrival at Destination - Day of Month',
#        'Arrival at Destination - Weekday (Mo = 1)', 'Distance (KM)',
#        'Time from Pickup to Arrival', 'No_Of_Orders', 'Age', 'No_of_Ratings',
#        'Proximity to Pickup Point', 'Proximity to Destination'],
#       dtype='object')

# %%
#Cate_Train = New_Data_Train.select_dtypes(include=['object'])
#Cate_Test = New_Data_Test.select_dtypes(include=['object'])
#Cate_Train.columns

# %%
Code_Cate_Train = pd.get_dummies(Numeric_Train_Data)
Code_Cate_Test = pd.get_dummies(Numeric_Test_Data )
Code_Cate_Train.head()
# Out:
#    Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# 0              3                         9                             5
# 1              3                        18                             5
# 2              3                        31                             5
# 3              3                         2                             2
# 4              2                        22                             2
#
#    Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# 0                            9                                5
# 1                           18                                5
# 2                           31                                5
# 3                            2                                2
# 4                           22                                2
#
#    Arrival at Pickup - Day of Month  Arrival at Pickup - Weekday (Mo = 1)  \
# ...

# %%
Code_Cate_Train = pd.get_dummies(Numeric_Train_Data)
Code_Cate_Test = pd.get_dummies(Numeric_Test_Data )
Code_Cate_Train.head()
# Out:
#    Platform Type  Placement - Day of Month  Placement - Weekday (Mo = 1)  \
# 0              3                         9                             5
# 1              3                        18                             5
# 2              3                        31                             5
# 3              3                         2                             2
# 4              2                        22                             2
#
#    Confirmation - Day of Month  Confirmation - Weekday (Mo = 1)  \
# 0                            9                                5
# 1                           18                                5
# 2                           31                                5
# 3                            2                                2
# 4                           22                                2
#
#    Arrival at Pickup - Day of Month  Arrival at Pickup - Weekday (Mo = 1)  \
# ...

# %%
# importing libraries 
import sys
from math import sqrt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
Testing=Merged_Test_Feature

# %%
New_Data_Train.to_csv('Training_Features.csv')
Testing.to_csv('Testing_Data.csv')

# %%
# Selecting the columns to be used as data for accuracy testing
X = Code_Cate_Train.drop('Time from Pickup to Arrival', axis = 1)
#assigning the target column
Y = Code_Cate_Train['Time from Pickup to Arrival']

# %%
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_Train)

X_test = sc.transform(X_Test)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /anaconda3/lib/python3.7/site-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   """

# %%
# Applying PCA
  
pca = PCA()
  
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
import sys
from math import sqrt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV, train_test_split

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet

# %%
# Fitting Linear regression 
linear_regress = LinearRegression()
linear_regress.fit(X_train, Y_Train)
y_pred_train_lr = linear_regress.predict(X_test)

print('RMSE:\t',np.sqrt(mean_squared_error(Y_Test,y_pred_train_lr)))
print('MSE:\t', mean_squared_error(Y_Test,y_pred_train_lr))
print("R2: \t", r2_score(Y_Test, y_pred_train_lr))
# Out:
# RMSE:	 786.2568960347027
# MSE:	 618199.9065621252
# R2: 	 0.3671237505771563

# %%
submission_file = pd.DataFrame({'Order_No': New_Data_Test['Order No'], 
                           'Time from Pickup to Arrival': y_pred_train_lr})
submission_file.to_csv('Sendy_logistic_challenge.csv',index = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-485-4b94b16e96ca> in <module>
#       1 submission_file = pd.DataFrame({'Order_No': New_Data_Test['Order No'],
# ----> 2                            'Time from Pickup to Arrival': y_pred_train_lr})
#       3 submission_file.to_csv('Sendy_logistic_challenge.csv',index = False)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
# ...
